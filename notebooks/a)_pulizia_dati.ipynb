# %% [markdown]
# ## **Pulizia dati Progetto Finale**

# %%
# Importazione Librerie
import pandas as pd
import numpy as np
from datetime import datetime, timezone

# %%
dist_center_raw=pd.read_csv("..\\data\\initial_data\\Distribution Center.csv")
events_raw=pd.read_csv("..\\data\\initial_data\\events.csv")
inv_items_raw=pd.read_csv("..\\data\\initial_data\\inventory_items.csv")
order_items_raw=pd.read_csv("..\\data\\initial_data\\order_items.csv")
orders_raw=pd.read_csv("..\\data\\initial_data\\orders.csv")
prod_raw=pd.read_csv("..\\data\\initial_data\\products.csv")
users_raw=pd.read_csv("..\\data\\initial_data\\Users.csv")

# %%
dist_center=dist_center_raw.copy()
events=events_raw.copy()
inv_items=inv_items_raw.copy()
order_items=order_items_raw.copy()
orders=orders_raw.copy()
prod=prod_raw.copy()
users=users_raw.copy()

# %% [markdown]
# ### Distribution Center

# %%
dist_center.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         10 non-null     int64
#  1   name       10 non-null     str
#  2   latitude   10 non-null     float64
#  3   longitude  10 non-null     float64
# dtypes: float64(2), int64(1), str(1)
# memory usage: 452.0 bytes

# %%
dist_center
# Out:
#    id                                         name  latitude  longitude
# 0   3                                   Houston TX   29.7604   -95.3698
# 1   7                              Philadelphia PA   39.9500   -75.1667
# 2   6  Port Authority of New York/New Jersey NY/NJ   40.6340   -73.7834
# 3   8                                    Mobile AL   30.6944   -88.0431
# 4   1                                   Memphis TN   35.1174   -89.9711
# 5   4                               Los Angeles CA   34.0500  -118.2500
# 6   2                                   Chicago IL   41.8369   -87.6847
# 7  10                                  Savannah GA   32.0167   -81.1167
# 8   9                                Charleston SC   32.7833   -79.9333
# 9   5                               New Orleans LA   29.9500   -90.0667

# %%
# Nessuna pulizia necessaria

# %%
dist_center.to_csv("..\\data\\clean_data\\distribution_center_clean.csv", index=False)

# %% [markdown]
# ### Events

# %%
events.info()
# Dati Mancanti in user_id (utenti non registrati)
# created_at da trasformare in data
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 680812 entries, 0 to 680811
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   session_id      680812 non-null  str
#  1   user_id         180812 non-null  float64
#  2   finish          680812 non-null  int64
#  3   event_type      680812 non-null  str
#  4   traffic_source  680812 non-null  str
#  5   state           680812 non-null  str
#  6   created_at      680812 non-null  str
# dtypes: float64(1), int64(1), str(5)
# memory usage: 36.4 MB

# %%
events["created_at"] = events["created_at"].str.replace(r"\.\d+", "", regex=True)
events["created_at"] = pd.to_datetime(events["created_at"], utc=True)

# %%
events["year"]=events["created_at"].dt.year
events["month"]=events["created_at"].dt.month

# %%
events=events[["session_id","user_id","finish","event_type","traffic_source","state","year","month"]]
events.sample(5)
# Out:
#                                   session_id  user_id  finish event_type  \
# 44470   aeabd7a3-aa57-40e2-8e6d-3e8745011c85  66814.0       7   purchase
# 589130  89a2a057-913c-4923-9d98-6db5249784a5      NaN       3       cart
# 208227  46ef6115-59ae-4202-8176-e9848470fe5d  74729.0       5   purchase
# 293657  9501b694-629a-45ae-a89a-909b2ac9c533      NaN       1    product
# 404615  54f7ed07-adad-4f89-938b-d1b009b9aba7      NaN       1    product
#
#        traffic_source                       state  year  month
# 44470           Email                       Hubei  2023      4
# 589130          Email                      Fujian  2024      8
# 208227          Email                     Sachsen  2026      2
# 293657          Email  Provence-Alpes-Côte d'Azur  2021     10
# 404615          Email                     England  2022      4

# %%
# Dopo aver pulito Users aggiungiamo il country a events e salviamo il file pulito

# %% [markdown]
# ### Inventory Items

# %%
inv_items.info()
# I Dati Mancanti in sold_at vanno mantenuti così come sono, il dato mancante ci fa capire che un pezzo è ancora in stock
# Cambiare created_at e sold_at in datetime
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 489823 entries, 0 to 489822
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              489823 non-null  int64
#  1   product_id                      489823 non-null  int64
#  2   created_at                      489823 non-null  str
#  3   sold_at                         181404 non-null  str
#  4   product_distribution_center_id  489823 non-null  int64
# dtypes: int64(3), str(2)
# memory usage: 18.7 MB

# %%
inv_items["created_at"] = inv_items["created_at"].str.replace(r"\.\d+", "", regex=True)
inv_items["created_at"] = pd.to_datetime(inv_items["created_at"], utc=True)
inv_items["sold_at"] = inv_items["sold_at"].str.replace(r"\.\d+", "", regex=True)
inv_items["sold_at"] = pd.to_datetime(inv_items["sold_at"], utc=True)

# %%
inv_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 489823 entries, 0 to 489822
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              489823 non-null  int64
#  1   product_id                      489823 non-null  int64
#  2   created_at                      489823 non-null  datetime64[us, UTC]
#  3   sold_at                         181404 non-null  datetime64[us, UTC]
#  4   product_distribution_center_id  489823 non-null  int64
# dtypes: datetime64[us, UTC](2), int64(3)
# memory usage: 18.7 MB

# %%
inv_items.sample(5)
# Out:
#             id  product_id                created_at  \
# 175286  142083        5074 2024-03-09 02:24:00+00:00
# 263950   20859       15327 2025-06-19 10:16:00+00:00
# 359000  289283        8981 2022-12-19 06:15:00+00:00
# 488600  130896       26282 2021-12-22 02:12:00+00:00
# 387837  126073       19455 2021-04-14 20:15:03+00:00
#
#                          sold_at  product_distribution_center_id
# 175286                       NaT                               5
# 263950                       NaT                               4
# 359000                       NaT                               5
# 488600                       NaT                               1
# 387837 2021-04-22 00:30:03+00:00                              10

# %%
# Se creo una variabile che assume valore 0 se il prodotto è stato venduto e 1 se è ancora in stock, posso eliminare sold_at
# Inoltre se aggiungo il mese e l'anno di creazione posso eliminare anche created_at
inv_items['in_stock'] = inv_items['sold_at'].isna().astype(int)
inv_items['month_year_creation'] = inv_items['created_at'].dt.strftime('%b %Y')
# magari posso aggiungere la durata di permanenza in stock (considerando i prodotti ancora non venduti come se venissero venduti alla data odierna)
oggi = datetime.now(timezone.utc).isoformat(sep=' ')
inv_items["sold_at"] = inv_items["sold_at"].fillna(oggi)
inv_items["time_in_stock"] = inv_items["sold_at"] - inv_items["created_at"]
inv_items["days_in_stock"] = inv_items["time_in_stock"].dt.days

# %%
inv_items=inv_items[["id", "product_id", "product_distribution_center_id", "in_stock", "month_year_creation", "days_in_stock"]]
# days_in_stock avrà valore null se non è ancora stato venduto

# %%
inv_items.sample(5)
# Out:
#             id  product_id  product_distribution_center_id  in_stock  \
# 395043   43063       19633                               4         0
# 58309   346245        8024                               3         0
# 332367  405218       10126                               5         1
# 24790   454607       28880                              10         1
# 40402   422689       18099                              10         1
#
#        month_year_creation  days_in_stock
# 395043            Jan 2026             44
# 58309             Jun 2025             10
# 332367            Jan 2026             35
# 24790             Oct 2022           1210
# 40402             Apr 2025            323

# %%
inv_items.to_csv("..\\data\\clean_data\\inventory_items_clean.csv", index=False)

# %% [markdown]
# ### Order Items

# %%
order_items.info()
# Dati Mancanti solo in shipped_at, delivered_at e returned_at. Vanno mantenuti, servono per capire lo stato dei vari prodotti dell'ordine
# Cambiare le variabili con date in DateTime
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 181404 entries, 0 to 181403
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 181404 non-null  int64
#  1   order_id           181404 non-null  int64
#  2   user_id            181404 non-null  int64
#  3   product_id         181404 non-null  int64
#  4   inventory_item_id  181404 non-null  int64
#  5   status             181404 non-null  str
#  6   created_at         181404 non-null  str
#  7   shipped_at         118292 non-null  str
#  8   delivered_at       63933 non-null   str
#  9   returned_at        18372 non-null   str
#  10  sale_price         181404 non-null  float64
# dtypes: float64(1), int64(5), str(5)
# memory usage: 15.2 MB

# %%
order_items["created_at"] = order_items["created_at"].str.replace(r"\.\d+", "", regex=True)
order_items["created_at"] = pd.to_datetime(order_items["created_at"], utc=True)
order_items["shipped_at"] = order_items["shipped_at"].str.replace(r"\.\d+", "", regex=True)
order_items["shipped_at"] = pd.to_datetime(order_items["shipped_at"], utc=True)
order_items["delivered_at"] = order_items["delivered_at"].str.replace(r"\.\d+", "", regex=True)
order_items["delivered_at"] = pd.to_datetime(order_items["delivered_at"], utc=True)
order_items["returned_at"] = order_items["returned_at"].str.replace(r"\.\d+", "", regex=True)
order_items["returned_at"] = pd.to_datetime(order_items["returned_at"], utc=True)

# %%
# Arrotondiamo sale_price
order_items["sale_price"]=order_items["sale_price"].round(2)

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 181404 entries, 0 to 181403
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 181404 non-null  int64
#  1   order_id           181404 non-null  int64
#  2   user_id            181404 non-null  int64
#  3   product_id         181404 non-null  int64
#  4   inventory_item_id  181404 non-null  int64
#  5   status             181404 non-null  str
#  6   created_at         181404 non-null  datetime64[us, UTC]
#  7   shipped_at         118292 non-null  datetime64[us, UTC]
#  8   delivered_at       63933 non-null   datetime64[us, UTC]
#  9   returned_at        18372 non-null   datetime64[us, UTC]
#  10  sale_price         181404 non-null  float64
# dtypes: datetime64[us, UTC](4), float64(1), int64(5), str(1)
# memory usage: 15.2 MB

# %%
order_items.sample(5)
# Out:
#             id  order_id  user_id  product_id  inventory_item_id      status  \
# 147765  118836     82024    65657       21017             320683   Cancelled
# 116211  137873     95110    76088       18587             372218   Cancelled
# 115215   85999     59523    47601       18033             232004  Processing
# 23981    13520      9394     7500       26394              36302    Complete
# 159501   62384     43153    34672        3571             168255    Returned
#
#                       created_at                shipped_at  \
# 147765 2024-08-22 00:27:30+00:00                       NaT
# 116211 2025-05-26 01:07:26+00:00                       NaT
# 115215 2024-05-19 01:14:19+00:00                       NaT
# 23981  2022-05-10 14:06:05+00:00 2022-05-08 18:04:49+00:00
# 159501 2023-11-22 13:44:08+00:00 2023-11-22 19:04:15+00:00
#
#                     delivered_at               returned_at  sale_price
# 147765                       NaT                       NaT       88.00
# 116211                       NaT                       NaT       54.22
# 115215                       NaT                       NaT       53.95
# 23981  2022-05-10 22:22:49+00:00                       NaT       15.95
# 159501 2023-11-26 17:32:15+00:00 2023-11-27 12:58:15+00:00      114.99

# %%
order_items=order_items[["id", "order_id", "user_id","product_id","inventory_item_id","status","sale_price"]]

# %%
order_items.sample(5)
# Out:
#             id  order_id  user_id  product_id  inventory_item_id      status  \
# 75570   124506     85914    68757       12323             336046  Processing
# 135523  114109     78804    63053       16628             307904  Processing
# 91793    44724     31045    25082       11856             120570    Complete
# 48050   179657    123802    99000       14853             485154     Shipped
# 82781   165476    114024    91226       21670             446787   Cancelled
#
#         sale_price
# 75570        34.25
# 135523       69.50
# 91793        40.00
# 48050        24.99
# 82781        36.99

# %%
# Dobbiamo ancora inserire il profitto dei singoli prodotti di ogni ordine. Poi salviamo il csv

# %% [markdown]
# ### Orders

# %%
orders.info()
# Dati Mancanti solo in shipped_at, delivered_at e returned_at. Vanno mantenuti, servono per capire lo stato dell'ordine
# Cambiare in datetime le variabili con le date
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124988 entries, 0 to 124987
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      124988 non-null  int64
#  1   user_id       124988 non-null  int64
#  2   status        124988 non-null  str
#  3   created_at    124988 non-null  str
#  4   returned_at   12635 non-null   str
#  5   shipped_at    81363 non-null   str
#  6   delivered_at  43863 non-null   str
#  7   num_of_item   124988 non-null  int64
# dtypes: int64(3), str(5)
# memory usage: 7.6 MB

# %%
orders["created_at"] = orders["created_at"].str.replace(r"\.\d+", "", regex=True)
orders["created_at"] = pd.to_datetime(orders["created_at"], utc=True)
orders["shipped_at"] = orders["shipped_at"].str.replace(r"\.\d+", "", regex=True)
orders["shipped_at"] = pd.to_datetime(orders["shipped_at"], utc=True)
orders["returned_at"] = orders["returned_at"].str.replace(r"\.\d+", "", regex=True)
orders["returned_at"] = pd.to_datetime(orders["returned_at"], utc=True)
orders["delivered_at"] = orders["delivered_at"].str.replace(r"\.\d+", "", regex=True)
orders["delivered_at"] = pd.to_datetime(orders["delivered_at"], utc=True)

# %%
orders.sample(5)
# Out:
#         order_id  user_id    status                created_at  \
# 114697     56703    45312   Shipped 2026-01-28 10:13:57+00:00
# 100398      8381     6686  Returned 2025-09-27 11:15:55+00:00
# 110573     29169    23484   Shipped 2023-09-14 01:43:40+00:00
# 55887      80237    64207   Shipped 2022-12-01 07:08:39+00:00
# 116316     67407    53952   Shipped 2025-11-13 22:38:07+00:00
#
#                      returned_at                shipped_at  \
# 114697                       NaT 2026-01-30 18:25:57+00:00
# 100398 2025-10-04 14:37:55+00:00 2025-09-30 04:56:55+00:00
# 110573                       NaT 2023-09-14 21:16:40+00:00
# 55887                        NaT 2022-12-02 14:23:39+00:00
# 116316                       NaT 2025-11-15 13:10:07+00:00
#
#                     delivered_at  num_of_item
# 114697                       NaT            1
# 100398 2025-10-03 06:51:55+00:00            1
# 110573                       NaT            1
# 55887                        NaT            1
# 116316                       NaT            2

# %%
# Se aggiungiamo il mese e l'anno di creazione. E calcoliamo il tempo per spedire un ordine e per farlo arrivare:
# Ci servono ancora created_at, shipped_at, delivered_at, returned_at?

# %%
# Aggiunta mese e anno di creazione ordine
orders['month_year_creation'] = orders['created_at'].dt.strftime('%b %Y')
# Aggiunta tempo di spedizione e di consegna
orders["time_for_shipping"] = orders["shipped_at"] - orders["created_at"]
orders["time_for_delivery"] = orders["delivered_at"] - orders["shipped_at"]
orders["days_for_shipping"] = orders["time_for_shipping"].dt.days
orders["days_for_delivery"] = orders["time_for_delivery"].dt.days

# %%
orders["year"]=orders["created_at"].dt.year
orders["month"]=orders["created_at"].dt.month

# %%
orders=orders[["order_id","user_id","status","num_of_item","month_year_creation","days_for_shipping","days_for_delivery","year","month"]]

# %%
orders.sample(5)
# Ovviamente rimangono dati mancanti in days_for_shipping e days_for_delivery in base allo stato dell'ordine
# Out:
#        order_id  user_id      status  num_of_item month_year_creation  \
# 10996     12819    10282    Complete            2            Mar 2024
# 51947     53672    42932     Shipped            1            Jul 2025
# 15180     46316    37170    Complete            1            Dec 2021
# 36396    114475    91606  Processing            1            Jul 2024
# 59270    103066    82458     Shipped            3            Dec 2025
#
#        days_for_shipping  days_for_delivery  year  month
# 10996                2.0                0.0  2024      3
# 51947                1.0                NaN  2025      7
# 15180                1.0                0.0  2021     12
# 36396                NaN                NaN  2024      7
# 59270                2.0                NaN  2025     12

# %%
"""
Vogliamo aggiungere il costo, il prezzo di vendita e il profitto per ogni ordine.
Come possiamo fare:
1. Facciamo una join tra order_items e products
2. Manteniamo nel nuovo dataframe solo order_id, product_id, sale_price e cost
3. Calcoliamo il profitto per ogni prodotto: sale_price-cost
4. Raggruppiamo per order_id e sommiamo i costi e il profitto
5. Facciamo una join tra il nuovo dataframe e orders
"""
# Out:
# '\nVogliamo aggiungere il costo, il prezzo di vendita e il profitto per ogni ordine.\nCome possiamo fare:\n1. Facciamo una join tra order_items e products\n2. Manteniamo nel nuovo dataframe solo order_id, product_id, sale_price e cost\n3. Calcoliamo il profitto per ogni prodotto: sale_price-cost\n4. Raggruppiamo per order_id e sommiamo i costi e il profitto\n5. Facciamo una join tra il nuovo dataframe e orders\n'

# %%
df_merged1 = pd.merge(left=order_items, right=prod, how='inner', left_on='product_id', right_on='id')
df_merged1=df_merged1[["order_id","product_id","sale_price","cost"]]
df_merged1["profit_per_product"]=df_merged1["sale_price"]-df_merged1["cost"]
df_merged1.sample(5)
# aggiungiamo il profitto dei singoli prodotti in order_items
# Out:
#         order_id  product_id  sale_price       cost  profit_per_product
# 63905     105078        6341       29.95  14.376000           15.574000
# 3827       71094       25185        8.00   4.472000            3.528000
# 94413      25613       10268       42.00  23.352000           18.648000
# 6917       89735       16426        9.95   5.572000            4.378000
# 143925     61247       28288       79.95  45.891298           34.058702

# %% [markdown]
# ### Finiamo di sitemare order_items

# %%
order_items=pd.merge(left=order_items, right=df_merged1, on=["order_id", "product_id"], how="left")

# %%
order_items=order_items[["id","order_id","user_id","product_id","inventory_item_id","status","sale_price_x","cost","profit_per_product"]]
order_items.rename(columns={"sale_price_x":"sale_price"}, inplace=True)

# %%
order_items.sample(5)
# Out:
#             id  order_id  user_id  product_id  inventory_item_id    status  \
# 12131    26529     18418    14758       24827              71388  Complete
# 18401    65309     45172    36253       18525             176245  Returned
# 64605   180491    124361    99461       14971             487393   Shipped
# 146122  145822    100650    80507        2349             393666  Returned
# 142916  131827     90922    72720       14415             355889   Shipped
#
#         sale_price      cost  profit_per_product
# 12131        11.99   6.61848             5.37152
# 18401        13.99   5.23226             8.75774
# 64605        29.98  11.72218            18.25782
# 146122       84.00  38.47200            45.52800
# 142916       79.00  36.49800            42.50200

# %%
order_items["cost"]=order_items["cost"].round(2)
order_items["profit_per_product"]=order_items["profit_per_product"].round(2)

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 181416 entries, 0 to 181415
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  181416 non-null  int64
#  1   order_id            181416 non-null  int64
#  2   user_id             181416 non-null  int64
#  3   product_id          181416 non-null  int64
#  4   inventory_item_id   181416 non-null  int64
#  5   status              181416 non-null  str
#  6   sale_price          181416 non-null  float64
#  7   cost                181416 non-null  float64
#  8   profit_per_product  181416 non-null  float64
# dtypes: float64(3), int64(5), str(1)
# memory usage: 12.5 MB

# %%
order_items.to_csv("..\\data\\clean_data\\order_items_clean.csv", index=False)

# %% [markdown]
# ### Torniamo ad orders

# %%
cost_prof_per_order=df_merged1.groupby("order_id", as_index=False).agg({"sale_price":sum, "cost": sum, "profit_per_product": sum})
cost_prof_per_order = cost_prof_per_order.rename(columns={"profit_per_product": "profit"})
cost_prof_per_order["profit"]=cost_prof_per_order["profit"].round(2)
cost_prof_per_order["cost"]=cost_prof_per_order["cost"].round(2)
cost_prof_per_order.head()
# Out:
#    order_id  sale_price   cost  profit
# 0         1       73.10  34.90   38.20
# 1         2      156.99  67.52   89.47
# 2         3       29.99  15.98   14.01
# 3         4       80.63  44.02   36.61
# 4         5      158.00  89.45   68.55

# %%
orders=pd.merge(left=orders, right=cost_prof_per_order, how='inner', on='order_id')
orders.sample(5)
# fare attenzione allo stato dell'ordine. tenere conto del profitto solo per ordini completati, spediti o in processo.
# Per ordini cancellati il profitto si azzera.
# Per gli ordini resi il profitto potrebbe diventare negativo (profitto=-costo). Decidere insieme.
# Out:
#        order_id  user_id      status  num_of_item month_year_creation  \
# 60474    111028    88891     Shipped            1            Apr 2024
# 14435     40113    32247    Complete            1            Dec 2025
# 62344    123610    98844     Shipped            1            Oct 2022
# 52264     55728    44559     Shipped            1            Nov 2023
# 97921    104046    83250  Processing            1            Aug 2023
#
#        days_for_shipping  days_for_delivery  year  month  sale_price    cost  \
# 60474                1.0                NaN  2024      4      129.00   61.79
# 14435                2.0                3.0  2025     12       12.99    5.01
# 62344                0.0                NaN  2022     10       44.99   22.23
# 52264                0.0                NaN  2023     11      246.00  123.25
# 97921                NaN                NaN  2023      8      189.00   91.10
#
#        profit
# 60474   67.21
# 14435    7.98
# 62344   22.76
# 52264  122.75
# 97921   97.90

# %%
# Modifica profitto in base allo status dell'ordine
orders.loc[orders['status'] == 'Cancelled', 'profit'] = 0
orders.loc[orders['status'] == 'Returned', 'profit'] = 0

# %%
orders.sample(5)
# Out:
#         order_id  user_id     status  num_of_item month_year_creation  \
# 20283      87087    69726   Complete            1            Feb 2026
# 73777      15575    12503   Complete            2            Dec 2025
# 65316      37163    29950  Cancelled            1            Apr 2025
# 103782     75495    60403   Returned            2            Mar 2024
# 118431     81620    65321    Shipped            1            Mar 2024
#
#         days_for_shipping  days_for_delivery  year  month  sale_price   cost  \
# 20283                 2.0                3.0  2026      2       98.00  53.21
# 73777                 0.0                4.0  2025     12       72.44  31.12
# 65316                 NaN                NaN  2025      4       42.00  22.76
# 103782                0.0                1.0  2024      3      118.64  48.16
# 118431                1.0                NaN  2024      3       24.00  10.99
#
#         profit
# 20283    44.79
# 73777    41.32
# 65316     0.00
# 103782    0.00
# 118431   13.01

# %%
orders.to_csv("..\\data\\clean_data\\orders_clean.csv", index=False)

# %% [markdown]
# ### Products

# %%
prod.info()
# name e brand con Dati Mancanti
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29120 entries, 0 to 29119
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      29120 non-null  int64
#  1   cost                    29120 non-null  float64
#  2   category                29120 non-null  str
#  3   name                    29118 non-null  str
#  4   brand                   29096 non-null  str
#  5   retail_price            29120 non-null  float64
#  6   department              29120 non-null  str
#  7   sku                     29120 non-null  str
#  8   distribution_center_id  29120 non-null  int64
# dtypes: float64(2), int64(2), str(5)
# memory usage: 2.0 MB

# %%
prod["brand"]=prod["brand"].fillna("Unknown")

# %%
prod=prod[["id","cost","category","brand","retail_price","department","distribution_center_id"]]

# %%
prod.sample(5)
# Out:
#           id    cost category               brand  retail_price department  \
# 2714   21557  48.118    Jeans        Silver Jeans          98.0        Men
# 6989    4463  15.090    Jeans       Alfred Dunner          30.0      Women
# 19987  21373  20.698    Jeans            Wrangler          39.5        Men
# 5236   12899  25.260     Swim             Sunsets          60.0      Women
# 24190   4753  43.508    Jeans  KUT from the Kloth          74.5      Women
#
#        distribution_center_id
# 2714                        1
# 6989                        2
# 19987                       7
# 5236                        2
# 24190                       8

# %%
"""
La variabile cost è il costo sostenuto dall'azienda per acquistare o produrre quel prodotto.
È un valore continuo, non arrotondato, e spesso deriva da:
- contratti con fornitori
- costi medi ponderati
- costi di produzione
- costi di importazione
- conversioni di valuta
- calcoli interni dell'azienda

Per questo ha molti decimali. Non è un errore, è semplicemente un valore “raw”, non arrotondato.
"""
# Out:
# "\nLa variabile cost è il costo sostenuto dall'azienda per acquistare o produrre quel prodotto.\nÈ un valore continuo, non arrotondato, e spesso deriva da:\n- contratti con fornitori\n- costi medi ponderati\n- costi di produzione\n- costi di importazione\n- conversioni di valuta\n- calcoli interni dell'azienda\n\nPer questo ha molti decimali. Non è un errore, è semplicemente un valore “raw”, non arrotondato.\n"

# %%
# Arrotondiamo cost e retail_price
prod["cost"]=prod["cost"].round(2)
prod["retail_price"]=prod["retail_price"].round(2)

# %%
# Non consideriamo i vari sconti del sale_price. Questo è il profitto ideale di ogni prodotto
prod["ideal_profit"]=prod["retail_price"]-prod["cost"]

# %%
prod.sample(5)
# Out:
#           id   cost                       category                   brand  \
# 26548  17530  31.21  Fashion Hoodies & Sweatshirts              Quiksilver
# 22336   8809  24.06              Outerwear & Coats                 Nautica
# 1488   13600   8.75                    Accessories                Isotoner
# 15116     93  16.92                    Tops & Tees              2b by bebe
# 24324  12577  21.48                      Intimates  PURE STYLE Girlfriends
#
#        retail_price department  distribution_center_id  ideal_profit
# 26548         59.00        Men                       9         27.79
# 22336         60.00      Women                       8         35.94
# 1488          24.44      Women                       1         15.69
# 15116         29.95      Women                       5         13.03
# 24324         40.37      Women                       8         18.89

# %%
prod.to_csv("..\\data\\clean_data\\products_clean.csv", index=False)

# %% [markdown]
# ### Users

# %%
users.info()
# city ha Dati Mancanti
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              100000 non-null  int64
#  1   first_name      100000 non-null  str
#  2   last_name       100000 non-null  str
#  3   age             100000 non-null  int64
#  4   gender          100000 non-null  str
#  5   state           100000 non-null  str
#  6   city            99005 non-null   str
#  7   country         100000 non-null  str
#  8   traffic_source  100000 non-null  str
# dtypes: int64(2), str(7)
# memory usage: 6.9 MB

# %%
users["city"]=users["city"].fillna("Unknown")

# %%
users["age"].describe()
# Out:
# count    100000.000000
# mean         40.949600
# std          17.023095
# min          12.000000
# 25%          26.000000
# 50%          41.000000
# 75%          56.000000
# max          70.000000
# Name: age, dtype: float64

# %%
# Aggiunta categorie età per future analisi
bins = [0, 25, 45, 65, np.inf] 
labels = [ "Young", "Adult", "Middle-aged Adult", "Senior"] 
users["age_group"] = pd.cut(users["age"], bins=bins, labels=labels, right=False)

# %%
users.sample(5)
# Out:
#           id first_name last_name  age gender       state         city  \
# 94180  31067    Raymond   Vazquez   18      M       Wales      Cardiff
# 78749  74103    Shannon    Abbott   44      F     Shaanxi     Shanghai
# 77409  35111      Kelli   Shepard   60      F       Seoul        Seoul
# 61375  23761       Mark    Howard   23      M  New Jersey  Long Branch
# 65564  52253   Savannah  Mitchell   39      F   Normandie        Rouen
#
#               country traffic_source          age_group
# 94180  United Kingdom         Search              Young
# 78749           China         Search              Adult
# 77409     South Korea         Search  Middle-aged Adult
# 61375   United States         Search              Young
# 65564          France         Search              Adult

# %%
users["country"].value_counts()
# Out:
# country
# China             34051
# United States     22456
# Brasil            14579
# South Korea        5230
# France             4813
# United Kingdom     4696
# Germany            4184
# Spain              3966
# Japan              2382
# Australia          2154
# Belgium            1252
# Poland              219
# Colombia             14
# Austria               2
# Deutschland           1
# España                1
# Name: count, dtype: int64

# %%
# Sostituiamo "Deutschland" con "Germany" e "Espana" con "Spain"
users["country"] = users["country"].replace({"Deutschland": "Germany", "España": "Spain"})

# %%
users["country"].value_counts()
# Out:
# country
# China             34051
# United States     22456
# Brasil            14579
# South Korea        5230
# France             4813
# United Kingdom     4696
# Germany            4185
# Spain              3967
# Japan              2382
# Australia          2154
# Belgium            1252
# Poland              219
# Colombia             14
# Austria               2
# Name: count, dtype: int64

# %%
users.to_csv("..\\data\\clean_data\\users_clean.csv", index=False)

# %% [markdown]
# ### Finiamo di sistemare events

# %%
# Aggiungiamo il country sfruttanfo state, che si trova anche nella tabella users
city_country_map = users[['state', 'country']].drop_duplicates()
events = events.merge(city_country_map, on='state', how='left')

# %%
events.sample(5)
# Out:
#                                   session_id  user_id  finish event_type  \
# 481868  80e95241-6cbd-48e2-9f7b-478dc9d4c07a      NaN       3     cancel
# 216762  182ecd7f-f2e6-42c8-8128-ecca64426152      NaN       3     cancel
# 248897  2fb9c434-a0e2-4ca1-a895-9c75034a6afa      NaN       2    product
# 666281  0d261f87-0898-4369-b9a1-4b845c62f264      NaN       1    product
# 246531  4f767f59-fa91-4659-ae14-b2cf7063d6cb      NaN       1    product
#
#        traffic_source       state  year  month        country
# 481868        YouTube       Hebei  2019      2          China
# 216762          Email   Guangdong  2021      4          China
# 248897        Adwords  Washington  2021      7  United States
# 666281        YouTube   Grand Est  2024      6         France
# 246531          Email       Texas  2026      2  United States

# %%
events.info()
# qualche dato mancante in Country
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 687427 entries, 0 to 687426
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   session_id      687427 non-null  str
#  1   user_id         182539 non-null  float64
#  2   finish          687427 non-null  int64
#  3   event_type      687427 non-null  str
#  4   traffic_source  687427 non-null  str
#  5   state           687427 non-null  str
#  6   year            687427 non-null  int32
#  7   month           687427 non-null  int32
#  8   country         687385 non-null  str
# dtypes: float64(1), int32(2), int64(1), str(5)
# memory usage: 42.0 MB

# %%
events["country"]=events["country"].fillna("Unknown")

# %%
events.to_csv("..\\data\\clean_data\\events_clean.csv", index=False)
